# %%
import pandas as pd

# %%
# !pip install sentence-transformers
# !pip install neo4j
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.32.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 47.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Collecting neo4j
#   Downloading neo4j-5.28.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j) (2025.2)
# Downloading neo4j-5.28.1-py3-none-any.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.3/312.3 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: neo4j
# Successfully installed neo4j-5.28.1

# %%
from sentence_transformers import SentenceTransformer
from neo4j import GraphDatabase
from IPython.display import display
from IPython.display import Markdown

# %%
df = pd.read_csv('/content/drive/MyDrive/receitas_dataset_atualizado11.csv')
df
# Out:
#                          Nome da Receita                       País  \
# 0                            Ratatouille                     França
# 1                               Feijoada                     Brasil
# 2                         Yakisoba Vegan                      Japão
# 3           Camarão com caldo de moqueca                     Brasil
# 4   Ravioli de Camarão com Massa Caseira                     Itália
# 5                       Brownie de Limão             Estados Unidos
# 6                      Boeuf Bourguignon                     França
# 7                                Pavlova  Austrália / Nova Zelândia
# 8                 Berinjela Mediterrânea                     Grécia
# 9                     Nhoque à Bolonhesa                     Itália
# 10                    Bacalhau com Natas                   Portugal
#
#                                          Ingredientes  \
# 0   Abobrinha, Berinjela, Tomate, Pimentão, Cebola...
# 1   Feijão preto, carne seca, linguiça, costelinha...
# 2   Macarrão de arroz, repolho, cenoura, brócolis,...
# 3   Camarão, azeite, suco do limão, 1 dente de alh...
# 4   2 xícaras de farinha de trigo, 2 ovos, 1 colhe...
# 5   1 xícara de farinha de trigo, 200g de chocolat...
# 6   1 kg de carne bovina para cozido, 150g de baco...
# 7   4 claras de ovo, 1 xícara de açúcar, 1 colher ...
# 8   2 berinjelas médias, 2 tomates maduros, 1 cebo...
# 9   500g de batata, 150g de farinha de trigo, 1 ov...
# 10  500g de bacalhau dessalgado e desfiado, 500g d...
#
#                                       Modo de Preparo   Porção Rendimento  \
# 0   1. Corte os legumes em rodelas. 2. Refogue alh...  1 prato  4 porções
# 1   1. Dessalgue as carnes. 2. Cozinhe o feijão co...  1 prato  6 porções
# 2   1. Cozinhe o macarrão. 2. Refogue legumes. 3. ...  1 prato  3 porções
# 3   1. Temperar o camarão: Camarão + limão + alho ...  1 prato  3 porções
# 4   \n        1. Fazer a massa: misturar farinha, ...  1 prato  3 porções
# 5   \n      1. Derreter o chocolate e a manteiga j...  1 fatia  8 porções
# 6   \n      1. Cortar a carne em cubos e dourar co...  1 prato  4 porções
# 7   \n      1. Preaquecer o forno a 120°C.\n      ...  1 fatia  6 porções
# 8   \n      1. Cortar as berinjelas em fatias ou c...  1 prato  4 porções
# 9   \n      1. Cozinhar as batatas, amassar e deix...  1 prato  4 porções
# 10  \n      1. Cozinhar as batatas, descascar e co...  1 prato  4 porções
#
#    Tempo de Preparo  Calorias  Proteínas  Carboidratos  Gorduras  Fibras  \
# 0        50 minutos       130          2            18         6       4
# 1           2 horas       550         30            40        28      10
# 2        40 minutos       300          8            45        10       6
# 3        40 minutos       400         25            25        25       4
# 4      1h20 minutos       500         25            50        20       2
# 5        45 minutos       375          5            48        22       2
# 6           3 horas       550         45            15        35       3
# 7      1h40 minutos       350          6            60        10       2
# 8        40 minutos       180          5            15        12       7
# 9      1h20 minutos       600         30            70        20       4
# 10     1h30 minutos       450         35            30        25       3
#
#                                Restrições Alimentares
# 0                           Vegana, Sem Glúten, Halal
# 1                                          Sem Glúten
# 2                  Vegana, Sem Lactose, Halal, Kosher
# 3                   Sem Lactose, camarão – alergênico
# 4   Contém glúten, ovos e frutos do mar; pode cont...
# 5   Contém glúten, ovos e leite; pode conter traço...
# 6   Contém glúten (farinha), contém carne bovina e...
# 7                               Contém ovos e lactose
# 8     Vegetariana; contém lactose se usar queijo feta
# 9                  Contém glúten, ovos e carne bovina
# 10  Contém lactose (creme, manteiga), glúten (fari...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nome da Receita         11 non-null     object
#  1   País                    11 non-null     object
#  2   Ingredientes            11 non-null     object
#  3   Modo de Preparo         11 non-null     object
#  4   Porção                  11 non-null     object
#  5   Rendimento              11 non-null     object
#  6   Tempo de Preparo        11 non-null     object
#  7   Calorias                11 non-null     int64
#  8   Proteínas               11 non-null     int64
#  9   Carboidratos            11 non-null     int64
#  10  Gorduras                11 non-null     int64
#  11  Fibras                  11 non-null     int64
#  12  Restrições Alimentares  11 non-null     object
# dtypes: int64(5), object(8)
# memory usage: 1.2+ KB

# %%
uri = "neo4j+s://72b87540.databases.neo4j.io"
user = "neo4j"
password = "Bnk9NEyU-6QJGvSSj05gs46trMpeKwBRr79v560E9d4"

try:
    driver = GraphDatabase.driver(uri, auth=(user, password))
    driver.verify_connectivity()
    print("Connected successfully!")
except Exception as e:
    print(f"Connection error: {e}")
# Out:
# Connected successfully!

# %%
def compile_text(x):

    text = f"""{x['Nome da Receita']}, {x['Ingredientes']}, {x['Modo de Preparo']}"""

    return text

# %%
sentences = df.apply(lambda x: compile_text(x), axis=1).tolist()
sentences
# Out:
# ['Ratatouille, Abobrinha, Berinjela, Tomate, Pimentão, Cebola, Alho, Azeite, Sal, Ervas finas, 1. Corte os legumes em rodelas. 2. Refogue alho e cebola no azeite. 3. Monte camadas em um refratário. 4. Asse por 40 min a 180ºC.',
#  'Feijoada, Feijão preto, carne seca, linguiça, costelinha, cebola, alho, louro, sal, pimenta, 1. Dessalgue as carnes. 2. Cozinhe o feijão com os temperos. 3. Adicione as carnes e cozinhe por 1h30.',
#  'Yakisoba Vegan, Macarrão de arroz, repolho, cenoura, brócolis, shoyu sem glúten, óleo de gergelim, 1. Cozinhe o macarrão. 2. Refogue legumes. 3. Adicione shoyu e óleo. 4. Misture tudo.',
#  'Camarão com caldo de moqueca, Camarão, azeite, suco do limão, 1 dente de alho picado, 1 cebola média, 1 pimentão verde picado, 2 tomates picados, pimenta do reino, folhas de coentro a gosto, 200ml de leite de coco, 1 colher de azeite de dendê, 1 banana da terra e sal., 1. Temperar o camarão: Camarão + limão + alho + sal + pimenta (marinar 20 min), \n        2. Refogar os vegetais: Azeite + cebola + pimentão + tomate (cozinhar até amolecer). \n        3. Adicionar leite de coco: Misturar ao refogado, ferver. \n        4. Cozinhar o camarão: Adicionar ao caldo, cozinhar até rosar (5-7 min). \n        5. Finalizar o prato: Acrescentar azeite de dendê + coentro.\n        6. Fritar banana-da-terra: Fatiar e dourar no azeite.\n        7. Servir: Com arroz branco + banana frita',
#  'Ravioli de Camarão com Massa Caseira, 2 xícaras de farinha de trigo, 2 ovos, 1 colher de sopa de azeite, 1 pitada de sal, camarão limpo picado, 1 dente de alho picado, azeite, salsinha ou coentro, sal, pimenta-do-reino, opcional: requeijão ou cream cheese, \n        1. Fazer a massa: misturar farinha, ovos, azeite e sal; sovar por 10 min; descansar 30 min.\n        2. Refogar alho no azeite; adicionar camarão, sal e pimenta; cozinhar 3 min; adicionar ervas; esfriar.\n        3. Abrir a massa fina; colocar recheio; cobrir com outra camada; fechar e cortar os raviolis.\n        4. Cozinhar em água fervente por 3-5 min até subir à superfície.\n        5. Servir com molho de sua preferência.',
#  'Brownie de Limão, 1 xícara de farinha de trigo, 200g de chocolate meio amargo, 150g de manteiga, 1 xícara de açúcar, 3 ovos, suco e raspas de 2 limões, 1 colher de chá de fermento em pó, 1 pitada de sal, \n      1. Derreter o chocolate e a manteiga juntos em banho-maria ou micro-ondas.\n      2. Misturar o açúcar e os ovos até formar um creme.\n      3. Adicionar o suco e as raspas de limão, misturar bem.\n      4. Incorporar o chocolate derretido na mistura.\n      5. Peneirar a farinha, fermento e sal e misturar delicadamente.\n      6. Despejar em forma untada e enfarinhada.\n      7. Assar em forno pré-aquecido a 180°C por 25-30 minutos.\n      8. Deixar esfriar antes de cortar e servir.',
#  'Boeuf Bourguignon, 1 kg de carne bovina para cozido, 150g de bacon, 2 cenouras, 1 cebola grande, 2 dentes de alho, 750ml de vinho tinto, 2 colheres de sopa de farinha de trigo, 200ml de caldo de carne, 1 bouquet garni (tomilho, louro, salsa), 200g de cogumelos, sal, pimenta-do-reino, azeite ou manteiga, \n      1. Cortar a carne em cubos e dourar com bacon em panela grande.\n      2. Retirar a carne; refogar cenoura, cebola e alho até amolecer.\n      3. Polvilhar farinha sobre os legumes e misturar.\n      4. Devolver a carne à panela; adicionar vinho tinto e caldo de carne.\n      5. Colocar bouquet garni; temperar com sal e pimenta.\n      6. Cozinhar em fogo baixo por 2-3 horas até a carne ficar macia.\n      7. Refogar cogumelos em manteiga e adicionar à carne nos últimos 30 minutos.\n      8. Servir quente, acompanhado de batatas ou pão.',
#  'Pavlova, 4 claras de ovo, 1 xícara de açúcar, 1 colher de chá de vinagre branco, 1 colher de chá de amido de milho, 1 colher de chá de essência de baunilha, creme de leite fresco para bater, frutas frescas (morango, kiwi, maracujá), \n      1. Preaquecer o forno a 120°C.\n      2. Bater as claras em neve até formar picos suaves.\n      3. Gradualmente adicionar o açúcar, batendo até obter picos firmes e brilhantes.\n      4. Incorporar delicadamente vinagre, amido de milho e baunilha.\n      5. Modelar a mistura em formato de disco em uma assadeira forrada com papel manteiga.\n      6. Assar por 1h e 15min, depois desligar o forno e deixar a pavlova esfriar dentro dele.\n      7. Bater o creme de leite até formar chantilly.\n      8. Cobrir a pavlova com chantilly e decorar com frutas frescas.\n      9. Servir imediatamente.',
#  'Berinjela Mediterrânea, 2 berinjelas médias, 2 tomates maduros, 1 cebola, 2 dentes de alho, azeite, azeitonas pretas, queijo feta (opcional), sal, pimenta-do-reino, orégano, manjericão fresco, \n      1. Cortar as berinjelas em fatias ou cubos e salgar para tirar o amargor; deixar descansar 20 min e enxaguar.\n      2. Refogar cebola e alho no azeite até ficarem macios.\n      3. Adicionar tomates picados, orégano, sal e pimenta; cozinhar até formar um molho.\n      4. Em uma travessa, misturar berinjela, molho, azeitonas e manjericão.\n      5. Se desejar, adicionar queijo feta por cima.\n      6. Levar ao forno pré-aquecido a 180°C por 20-25 minutos.\n      7. Servir quente ou frio como entrada ou acompanhamento.',
#  'Nhoque à Bolonhesa, 500g de batata, 150g de farinha de trigo, 1 ovo, sal, 300g de carne moída, 1 cebola, 2 dentes de alho, 400g de molho de tomate, azeite, sal, pimenta-do-reino, queijo parmesão ralado, \n      1. Cozinhar as batatas, amassar e deixar esfriar.\n      2. Misturar batata, farinha, ovo e sal até formar uma massa homogênea.\n      3. Fazer rolinhos com a massa, cortar em pedaços pequenos e formar os nhoques.\n      4. Cozinhar os nhoques em água fervente até subirem à superfície; escorrer.\n      5. Refogar cebola e alho no azeite, adicionar carne moída e cozinhar até dourar.\n      6. Acrescentar molho de tomate, temperar com sal e pimenta; cozinhar por 20 minutos.\n      7. Servir o molho sobre o nhoque e polvilhar com queijo parmesão.',
#  'Bacalhau com Natas, 500g de bacalhau dessalgado e desfiado, 500g de batatas, 1 cebola grande, 2 dentes de alho, 200ml de creme de leite, 100ml de leite, 2 colheres de sopa de manteiga, 2 colheres de sopa de farinha de trigo, azeite, sal, pimenta-do-reino, noz-moscada, salsa picada, \n      1. Cozinhar as batatas, descascar e cortar em cubos.\n      2. Refogar cebola e alho no azeite até ficarem macios.\n      3. Adicionar o bacalhau desfiado e misturar.\n      4. Fazer um molho branco: derreter manteiga, adicionar farinha, mexer e juntar leite e creme até engrossar; temperar com sal, pimenta e noz-moscada.\n      5. Misturar o bacalhau com as batatas e o molho branco.\n      6. Colocar em um refratário untado, polvilhar com salsa.\n      7. Levar ao forno preaquecido a 180°C por cerca de 20 minutos até dourar.\n      8. Servir quente.']

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
output = model.encode(sentences=sentences,
         show_progress_bar=True,
         normalize_embeddings=True)

embeddings = pd.DataFrame(output)
embeddings
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#          0         1         2         3         4         5         6    \
# 0   0.038825  0.033433 -0.024920 -0.037155 -0.050077 -0.003637 -0.015536
# 1  -0.031496  0.054727  0.005606  0.061651 -0.093837  0.055785  0.036712
# 2  -0.053101 -0.003277 -0.056792 -0.027380 -0.005229 -0.015801  0.025470
# 3   0.004529 -0.009535 -0.028582 -0.007879  0.038132  0.011468  0.011419
# 4  -0.007436 -0.009575 -0.030793 -0.021885 -0.000660  0.018300  0.015557
# 5  -0.012102 -0.001891 -0.021348  0.032537  0.005409  0.003099  0.022924
# 6  -0.058192  0.022435 -0.027848 -0.000847 -0.070559 -0.014390 -0.006731
# 7  -0.028677  0.034374 -0.029265 -0.013350 -0.064998  0.029822 -0.054755
# 8   0.007145  0.049405  0.024006 -0.001931 -0.051345 -0.011110 -0.049305
# 9  -0.003356  0.073449 -0.039319 -0.028232 -0.035940 -0.032974 -0.034787
# 10  0.019535  0.021499 -0.026757 -0.000123 -0.070825 -0.060644 -0.033303
#
#          7         8         9    ...       374       375       376       377  \
# 0   0.056863  0.019638  0.086313  ... -0.031731 -0.012649  0.058094 -0.037309
# 1   0.112191 -0.024520  0.044457  ... -0.044243  0.013020 -0.012371  0.020365
# 2  -0.005153 -0.015756 -0.032096  ... -0.102677 -0.005196  0.068098 -0.124268
# 3   0.081042  0.006641  0.089228  ... -0.026303 -0.043148  0.091383 -0.009509
# 4   0.115663  0.010710 -0.021585  ... -0.031167 -0.026653  0.067887 -0.008003
# 5   0.070404  0.048961  0.005198  ...  0.012211 -0.103572  0.032023 -0.016085
# 6   0.049758  0.013611 -0.022695  ... -0.034248 -0.021986  0.028353  0.002404
# 7   0.057975  0.000147  0.022925  ... -0.046750 -0.059593  0.021124  0.010765
# 8   0.052365  0.032305  0.060451  ... -0.026988 -0.050966  0.043381  0.072956
# 9   0.094157  0.026014  0.097031  ... -0.072993 -0.013045 -0.005656 -0.038436
# 10  0.069505  0.003893  0.034695  ... -0.077934 -0.019477 -0.006099  0.022575
#
#          378       379       380       381       382       383
# 0   0.068249  0.001395  0.016805  0.083046  0.024491  0.035807
# 1   0.000599 -0.086518  0.034004  0.054162 -0.019206  0.051577
# 2   0.047262 -0.034022  0.050475 -0.016143  0.034840  0.074671
# 3   0.013531  0.041153  0.013440  0.023344 -0.033295 -0.025673
# 4   0.055837 -0.034055  0.063059  0.040639 -0.030815 -0.032252
# 5  -0.007148 -0.059104  0.091307  0.030510 -0.050170 -0.002532
# 6   0.113258 -0.055967 -0.015750  0.074861  0.019011 -0.004387
# 7   0.068815 -0.043701  0.068431 -0.022131 -0.018217 -0.005263
# 8   0.056892 -0.005995  0.031659  0.077233 -0.010010 -0.031427
# 9   0.075070 -0.042467  0.090947  0.012569 -0.014810 -0.008131
# 10  0.060944 -0.042633  0.088702  0.011640  0.001343 -0.029327
#
# [11 rows x 384 columns]

# %%
df["Embedding"] = embeddings.values.tolist()
df
# Out:
#                          Nome da Receita                       País  \
# 0                            Ratatouille                     França
# 1                               Feijoada                     Brasil
# 2                         Yakisoba Vegan                      Japão
# 3           Camarão com caldo de moqueca                     Brasil
# 4   Ravioli de Camarão com Massa Caseira                     Itália
# 5                       Brownie de Limão             Estados Unidos
# 6                      Boeuf Bourguignon                     França
# 7                                Pavlova  Austrália / Nova Zelândia
# 8                 Berinjela Mediterrânea                     Grécia
# 9                     Nhoque à Bolonhesa                     Itália
# 10                    Bacalhau com Natas                   Portugal
#
#                                          Ingredientes  \
# 0   Abobrinha, Berinjela, Tomate, Pimentão, Cebola...
# 1   Feijão preto, carne seca, linguiça, costelinha...
# 2   Macarrão de arroz, repolho, cenoura, brócolis,...
# 3   Camarão, azeite, suco do limão, 1 dente de alh...
# 4   2 xícaras de farinha de trigo, 2 ovos, 1 colhe...
# 5   1 xícara de farinha de trigo, 200g de chocolat...
# 6   1 kg de carne bovina para cozido, 150g de baco...
# 7   4 claras de ovo, 1 xícara de açúcar, 1 colher ...
# 8   2 berinjelas médias, 2 tomates maduros, 1 cebo...
# 9   500g de batata, 150g de farinha de trigo, 1 ov...
# 10  500g de bacalhau dessalgado e desfiado, 500g d...
#
#                                       Modo de Preparo   Porção Rendimento  \
# 0   1. Corte os legumes em rodelas. 2. Refogue alh...  1 prato  4 porções
# 1   1. Dessalgue as carnes. 2. Cozinhe o feijão co...  1 prato  6 porções
# 2   1. Cozinhe o macarrão. 2. Refogue legumes. 3. ...  1 prato  3 porções
# 3   1. Temperar o camarão: Camarão + limão + alho ...  1 prato  3 porções
# 4   \n        1. Fazer a massa: misturar farinha, ...  1 prato  3 porções
# 5   \n      1. Derreter o chocolate e a manteiga j...  1 fatia  8 porções
# 6   \n      1. Cortar a carne em cubos e dourar co...  1 prato  4 porções
# 7   \n      1. Preaquecer o forno a 120°C.\n      ...  1 fatia  6 porções
# 8   \n      1. Cortar as berinjelas em fatias ou c...  1 prato  4 porções
# 9   \n      1. Cozinhar as batatas, amassar e deix...  1 prato  4 porções
# 10  \n      1. Cozinhar as batatas, descascar e co...  1 prato  4 porções
#
#    Tempo de Preparo  Calorias  Proteínas  Carboidratos  Gorduras  Fibras  \
# 0        50 minutos       130          2            18         6       4
# 1           2 horas       550         30            40        28      10
# 2        40 minutos       300          8            45        10       6
# 3        40 minutos       400         25            25        25       4
# 4      1h20 minutos       500         25            50        20       2
# 5        45 minutos       375          5            48        22       2
# 6           3 horas       550         45            15        35       3
# 7      1h40 minutos       350          6            60        10       2
# 8        40 minutos       180          5            15        12       7
# 9      1h20 minutos       600         30            70        20       4
# 10     1h30 minutos       450         35            30        25       3
#
#                                Restrições Alimentares  \
# 0                           Vegana, Sem Glúten, Halal
# 1                                          Sem Glúten
# 2                  Vegana, Sem Lactose, Halal, Kosher
# 3                   Sem Lactose, camarão – alergênico
# 4   Contém glúten, ovos e frutos do mar; pode cont...
# 5   Contém glúten, ovos e leite; pode conter traço...
# 6   Contém glúten (farinha), contém carne bovina e...
# 7                               Contém ovos e lactose
# 8     Vegetariana; contém lactose se usar queijo feta
# 9                  Contém glúten, ovos e carne bovina
# 10  Contém lactose (creme, manteiga), glúten (fari...
#
#                                             Embedding
# 0   [0.03882530704140663, 0.033433470875024796, -0...
# 1   [-0.03149561211466789, 0.05472691357135773, 0....
# 2   [-0.053100958466529846, -0.003277126932516694,...
# 3   [0.0045291967689991, -0.009534711949527264, -0...
# 4   [-0.007436313666403294, -0.009575122967362404,...
# 5   [-0.012101584114134312, -0.0018908054335042834...
# 6   [-0.058191776275634766, 0.022435320541262627, ...
# 7   [-0.02867692895233631, 0.03437428176403046, -0...
# 8   [0.007144713308662176, 0.049404509365558624, 0...
# 9   [-0.0033562621101737022, 0.0734485536813736, -...
# 10  [0.019534843042492867, 0.021498529240489006, -...

# %%
def create_nodes_and_relationships(df):
    with driver.session() as session:
        session.run("MATCH (n) DETACH DELETE n")

        for _, row in df.iterrows():
            session.run(
                """
                MERGE (r:Receita {
                    nome: $nome,
                    tempo_preparo: $tempo_preparo,
                    porcao: $porcao,
                    rendimento: $rendimento,
                    ingredientes: $ingredientes,
                    modo_preparo: $modo_preparo,
                    calorias: $calorias,
                    proteinas: $proteinas,
                    carboidratos: $carboidratos,
                    gorduras: $gorduras,
                    fibras: $fibras,
                    restricoes: $restricoes
                })
                MERGE (em:Embedding {embedding: $embedding})
                MERGE (em)-[:VETOR_DENSO_DE]->(r)

                """,
                nome=row["Nome da Receita"],
                tempo_preparo=row["Tempo de Preparo"],
                porcao=row["Porção"],
                rendimento=row["Rendimento"],
                ingredientes=row["Ingredientes"],
                modo_preparo=row["Modo de Preparo"],
                calorias=int(row["Calorias"]),
                proteinas=int(row["Proteínas"]),
                carboidratos=int(row["Carboidratos"]),
                gorduras=int(row["Gorduras"]),
                fibras=int(row["Fibras"]),
                restricoes=row["Restrições Alimentares"],
                embedding=row["Embedding"]
            )
        print('Nodos e relacionamentos criados com sucesso!')

# %%
df.fillna('')
# Out:
#                          Nome da Receita                       País  \
# 0                            Ratatouille                     França
# 1                               Feijoada                     Brasil
# 2                         Yakisoba Vegan                      Japão
# 3           Camarão com caldo de moqueca                     Brasil
# 4   Ravioli de Camarão com Massa Caseira                     Itália
# 5                       Brownie de Limão             Estados Unidos
# 6                      Boeuf Bourguignon                     França
# 7                                Pavlova  Austrália / Nova Zelândia
# 8                 Berinjela Mediterrânea                     Grécia
# 9                     Nhoque à Bolonhesa                     Itália
# 10                    Bacalhau com Natas                   Portugal
#
#                                          Ingredientes  \
# 0   Abobrinha, Berinjela, Tomate, Pimentão, Cebola...
# 1   Feijão preto, carne seca, linguiça, costelinha...
# 2   Macarrão de arroz, repolho, cenoura, brócolis,...
# 3   Camarão, azeite, suco do limão, 1 dente de alh...
# 4   2 xícaras de farinha de trigo, 2 ovos, 1 colhe...
# 5   1 xícara de farinha de trigo, 200g de chocolat...
# 6   1 kg de carne bovina para cozido, 150g de baco...
# 7   4 claras de ovo, 1 xícara de açúcar, 1 colher ...
# 8   2 berinjelas médias, 2 tomates maduros, 1 cebo...
# 9   500g de batata, 150g de farinha de trigo, 1 ov...
# 10  500g de bacalhau dessalgado e desfiado, 500g d...
#
#                                       Modo de Preparo   Porção Rendimento  \
# 0   1. Corte os legumes em rodelas. 2. Refogue alh...  1 prato  4 porções
# 1   1. Dessalgue as carnes. 2. Cozinhe o feijão co...  1 prato  6 porções
# 2   1. Cozinhe o macarrão. 2. Refogue legumes. 3. ...  1 prato  3 porções
# 3   1. Temperar o camarão: Camarão + limão + alho ...  1 prato  3 porções
# 4   \n        1. Fazer a massa: misturar farinha, ...  1 prato  3 porções
# 5   \n      1. Derreter o chocolate e a manteiga j...  1 fatia  8 porções
# 6   \n      1. Cortar a carne em cubos e dourar co...  1 prato  4 porções
# 7   \n      1. Preaquecer o forno a 120°C.\n      ...  1 fatia  6 porções
# 8   \n      1. Cortar as berinjelas em fatias ou c...  1 prato  4 porções
# 9   \n      1. Cozinhar as batatas, amassar e deix...  1 prato  4 porções
# 10  \n      1. Cozinhar as batatas, descascar e co...  1 prato  4 porções
#
#    Tempo de Preparo  Calorias  Proteínas  Carboidratos  Gorduras  Fibras  \
# 0        50 minutos       130          2            18         6       4
# 1           2 horas       550         30            40        28      10
# 2        40 minutos       300          8            45        10       6
# 3        40 minutos       400         25            25        25       4
# 4      1h20 minutos       500         25            50        20       2
# 5        45 minutos       375          5            48        22       2
# 6           3 horas       550         45            15        35       3
# 7      1h40 minutos       350          6            60        10       2
# 8        40 minutos       180          5            15        12       7
# 9      1h20 minutos       600         30            70        20       4
# 10     1h30 minutos       450         35            30        25       3
#
#                                Restrições Alimentares  \
# 0                           Vegana, Sem Glúten, Halal
# 1                                          Sem Glúten
# 2                  Vegana, Sem Lactose, Halal, Kosher
# 3                   Sem Lactose, camarão – alergênico
# 4   Contém glúten, ovos e frutos do mar; pode cont...
# 5   Contém glúten, ovos e leite; pode conter traço...
# 6   Contém glúten (farinha), contém carne bovina e...
# 7                               Contém ovos e lactose
# 8     Vegetariana; contém lactose se usar queijo feta
# 9                  Contém glúten, ovos e carne bovina
# 10  Contém lactose (creme, manteiga), glúten (fari...
#
#                                             Embedding
# 0   [0.03882530704140663, 0.033433470875024796, -0...
# 1   [-0.03149561211466789, 0.05472691357135773, 0....
# 2   [-0.053100958466529846, -0.003277126932516694,...
# 3   [0.0045291967689991, -0.009534711949527264, -0...
# 4   [-0.007436313666403294, -0.009575122967362404,...
# 5   [-0.012101584114134312, -0.0018908054335042834...
# 6   [-0.058191776275634766, 0.022435320541262627, ...
# 7   [-0.02867692895233631, 0.03437428176403046, -0...
# 8   [0.007144713308662176, 0.049404509365558624, 0...
# 9   [-0.0033562621101737022, 0.0734485536813736, -...
# 10  [0.019534843042492867, 0.021498529240489006, -...

# %%
def clean_nan_values(df):
    return df.fillna("")
df = clean_nan_values(df)

# %%
create_nodes_and_relationships(df)
# Out:
# Nodos e relacionamentos criados com sucesso!

# %%
def get_embedding(query):
    return model.encode(query).tolist()

# %%
def search_similar_products(query):
    query_embedding = get_embedding(query)
    with driver.session() as session:
        result = session.run(
            """
            WITH $query_embedding AS queryVec
            MATCH (em:Embedding)-[:VETOR_DENSO_DE]->(r:Receita)
            WITH r, vector.similarity.cosine(queryVec, em.embedding) AS similarity
            WHERE similarity >= 0.4
            RETURN r.nome AS receita, similarity
            ORDER BY similarity DESC
            LIMIT 5
            """,
            query_embedding=query_embedding
        )
        return result.data()

# %%
sentence = "Eu tenho berinjela, abobrinha e tomate, o que posso fazer com esses ingredientes?"
similar_products = search_similar_products(sentence)
similar_products
# Out:
# [{'receita': 'Berinjela Mediterrânea', 'similarity': 0.7847647666931152},
#  {'receita': 'Ratatouille', 'similarity': 0.7762736082077026},
#  {'receita': 'Boeuf Bourguignon', 'similarity': 0.7636440396308899},
#  {'receita': 'Bacalhau com Natas', 'similarity': 0.7431693077087402},
#  {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.7340882420539856}]

# %%
sentence = "Estou fazendo uma dieta e gostaria de uma receita com baixo teor calórico e rica em proteínas."
similar_products = search_similar_products(sentence)
similar_products
# Out:
# [{'receita': 'Yakisoba Vegan', 'similarity': 0.7459560632705688},
#  {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.736324667930603},
#  {'receita': 'Bacalhau com Natas', 'similarity': 0.7186410427093506},
#  {'receita': 'Boeuf Bourguignon', 'similarity': 0.7142635583877563},
#  {'receita': 'Brownie de Limão', 'similarity': 0.7098664045333862}]

# %%
sentence = "Quais receitas têm menos de 400 calorias e mais de 20g de proteína por porção?"
similar_products = search_similar_products(sentence)
similar_products
# Out:
# [{'receita': 'Bacalhau com Natas', 'similarity': 0.7464921474456787},
#  {'receita': 'Nhoque à Bolonhesa', 'similarity': 0.7149672508239746},
#  {'receita': 'Boeuf Bourguignon', 'similarity': 0.7100570797920227},
#  {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.700055718421936},
#  {'receita': 'Berinjela Mediterrânea', 'similarity': 0.6947089433670044}]

# %%
sentence = "Possuo em casa: feijão, arroz, carne em casa, qual receita eu poderia fazer?"
similar_products = search_similar_products(sentence)
similar_products
# Out:
# [{'receita': 'Feijoada', 'similarity': 0.8013175129890442},
#  {'receita': 'Berinjela Mediterrânea', 'similarity': 0.7195606827735901},
#  {'receita': 'Nhoque à Bolonhesa', 'similarity': 0.7178099155426025},
#  {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.7120342254638672},
#  {'receita': 'Ratatouille', 'similarity': 0.7083571553230286}]

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# %%
from google.colab import userdata
userdata.get('gemini_key')
# Out:
# 'AIzaSyB6Pj_Vn1WRTUR-cQ3Ln_4WM7OniuI73JI'

# %%
Gemini_Key=userdata.get('gemini_key')

genai.configure(api_key=Gemini_Key)

# %%
modelGemini = genai.GenerativeModel('gemini-1.5-flash')

# %%
prompt = """Eu tenho berinjela, abobrinha e tomate, o que posso fazer com esses ingredientes?
          Resultado:
          {'receita': 'Berinjela Mediterrânea', 'similarity': 0.7847647666931152},
          {'receita': 'Ratatouille', 'similarity': 0.7762736082077026},
          {'receita': 'Boeuf Bourguignon', 'similarity': 0.7636440396308899},
          {'receita': 'Bacalhau com Natas', 'similarity': 0.7431693077087402},
          {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.7340882420539856}

Com base nas avaliações dos produtos apresentados, analise cada um deles em relação à sua busca.
"""

# %%
from IPython.display import display, Markdown

# %%
response = model.generate_content(f"{prompt} ")
display(Markdown(response.text))
# Out:
# A busca por receitas utilizando berinjela, abobrinha e tomate retorna resultados que demonstram uma forte correlação com pratos mediterrâneos e de origem francesa, com foco em vegetais. Vamos analisar cada sugestão:
#
#
# * **Berinjela Mediterrânea (Similaridade: 0.78):**  Essa é a sugestão mais semelhante à combinação de ingredientes.  A berinjela é o ingrediente principal, e abobrinha e tomate são ótimos acompanhamentos em pratos mediterrâneos, como moussakas ou outras preparações assadas ou grelhadas com ervas e especiarias.  A alta similaridade indica uma boa adequação.
#
#
# * **Ratatouille (Similaridade: 0.77):**  Um clássico da culinária francesa, o Ratatouille é uma combinação perfeita dos três ingredientes.  A abobrinha, berinjela e tomate são os pilares dessa receita de vegetais cozidos em azeite, ervas e especiarias. A alta similaridade é esperada e justificada.
#
#
# * **Boeuf Bourguignon (Similaridade: 0.76):**  Este é um resultado surpreendente.  Embora o Boeuf Bourguignon contenha tomate, a berinjela e a abobrinha não são ingredientes tradicionais. A similaridade relativamente alta pode ser explicada pelo tomate, um componente chave no molho da receita, mas a ausência dos outros dois ingredientes torna esta opção menos adequada que as anteriores. A receita provavelmente utiliza o tomate como base para um molho, e a similaridade é mais fraca do que as outras devido à presença apenas de um dos três ingredientes principais.
#
#
# * **Bacalhau com Natas (Similaridade: 0.74):** Este resultado é ainda mais inesperado. O bacalhau é o ingrediente principal e os outros três ingredientes são usados como acompanhamento, com o tomate na composição de um molho. A baixa similaridade indica que a relação entre os ingredientes da sua busca e esta receita é pequena.
#
#
# * **Camarão com caldo de moqueca (Similaridade: 0.73):**  Similar ao caso do Bacalhau com Natas, a similaridade é baixa.  O tomate pode ser usado no caldo da moqueca, mas berinjela e abobrinha são totalmente ausentes.
#
#
# **Conclusão:**
#
# As melhores opções para utilizar berinjela, abobrinha e tomate, com base nas similaridades apresentadas, são **Berinjela Mediterrânea** e **Ratatouille**.  As outras sugestões são menos adequadas, demonstrando como o algoritmo de recomendação leva em consideração a presença de *pelo menos um* ingrediente, mesmo que os outros sejam irrelevantes para a receita. A similaridade quantifica a força da relação entre os ingredientes na busca e os ingredientes de cada receita.

# %%
prompt = """
    Você é um assistente especializado em receitas culinárias, que conhece detalhes como ingredientes, modo de preparo, valores nutricionais, tempo e rendimento.
    Use as informações para responder perguntas sobre receitas, ingredientes, restrições alimentares, tempo de preparo e sugestões.
    Responda de forma clara e direta. Caso a pergunta envolva ingredientes específicos, sugira receitas que usem esses ingredientes.
    Sempre informe o nome da receita e detalhes importantes (tempo, porção, principais nutrientes).
"""

# %%
pergunta = "Tem alguma receita com poucas calorias e que tenha alto teor de proteínas?"

# %%
prompt = f"""{prompt} Pergunta: {pergunta} de acordo com {df}"""

response = model.generate_content(prompt)
display(Markdown(response.text))
# Out:
# Das receitas listadas, a **Boeuf Bourguignon** (França) é a que melhor se encaixa na sua busca por uma opção com poucas calorias e alto teor de proteína, considerando a proporção entre os dois nutrientes.
#
# **Boeuf Bourguignon:**
#
# * **Tempo de preparo:** 3 horas
# * **Porção:** 1 prato
# * **Rendimento:** 4 porções
# * **Calorias:** 550 kcal (por porção)
# * **Proteínas:** 45g (por porção)  -  Alto teor de proteína em comparação às outras opções.
# * **Carboidratos:** 15g (por porção) - Baixo teor de carboidratos em relação às outras opções.
# * **Gorduras:** 35g (por porção) -  Apesar de ter uma quantidade considerável de gordura, é importante notar a alta quantidade de proteína, compensando em parte esse valor.
#
# **Observações:**  Embora não seja a opção com menos calorias na lista, a Boeuf Bourguignon apresenta um balanço mais favorável entre calorias e proteína, comparada às demais. Se você precisar de uma opção ainda mais baixa em calorias, considere o Ratatouille ou a Berinjela Mediterrânea, mas lembre-se que o teor de proteína nessas opções será significativamente menor.

# %%
prompt = """Eu tenho berinjela, abobrinha e tomate, o que posso fazer com esses ingredientes?
          Resultado:
          {'receita': 'Berinjela Mediterrânea', 'similarity': 0.7847647666931152},
          {'receita': 'Ratatouille', 'similarity': 0.7762736082077026},
          {'receita': 'Boeuf Bourguignon', 'similarity': 0.7636440396308899},
          {'receita': 'Bacalhau com Natas', 'similarity': 0.7431693077087402},
          {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.7340882420539856}

Com base nas avaliações dos produtos apresentados, analise cada um deles em relação à sua busca.
"""

# %%
response = modelGemini.generate_content(f"{prompt}, para a receita mais semelhante, gere a receita passo a passo de acordo com {df}")
display(Markdown(response.text))
# Out:
# A sua busca por receitas com berinjela, abobrinha e tomate retorna a `Ratatouille` como a receita mais semelhante (similaridade de 0.776).  Vamos analisar as outras sugestões:
#
# * **Ratatouille (Similaridade: 0.776):**  Essa é uma excelente sugestão, pois os ingredientes principais da receita são exatamente os que você tem. É uma receita clássica francesa, simples e saborosa.
#
# * **Berinjela Mediterrânea (Similaridade: 0.785):** Também uma boa opção, já que inclui berinjela como ingrediente principal.  Provavelmente, utilizará os tomates e possivelmente, outras verduras além da berinjela e abobrinha.
#
# * **Boeuf Bourguignon (Similaridade: 0.764):**  Esta receita francesa de carne de boi cozida no vinho tinto *não* utiliza abobrinha ou berinjela como ingredientes principais. A similaridade provavelmente vem do uso de tomates no molho.  Você precisaria adicionar outros ingredientes (carne, vinho, etc.).
#
# * **Bacalhau com Natas (Similaridade: 0.743) e Camarão com caldo de moqueca (Similaridade: 0.734):**  Ambas as receitas têm pouca relação com seus ingredientes.  A similaridade pode ser atribuída ao uso de tomates em alguns molhos, mas são receitas bem diferentes.
#
#
# **Receita passo a passo para Ratatouille:**
#
# **Ingredientes:**
#
# * 1 berinjela média, cortada em cubos
# * 1 abobrinha média, cortada em cubos
# * 2 tomates médios maduros, picados (ou 1 lata de tomate picado)
# * 1 cebola média, picada
# * 1 pimentão médio (de qualquer cor), picado (opcional, mas recomendado para um Ratatouille completo)
# * 2 dentes de alho, picados
# * 2 colheres de sopa de azeite de oliva
# * Orégano a gosto
# * Manjericão fresco a gosto
# * Sal e pimenta do reino a gosto
# * Uma pitada de açúcar (opcional, ajuda a equilibrar a acidez dos tomates)
#
#
# **Modo de Preparo:**
#
# 1. **Preparo dos legumes:** Lave e corte todos os legumes em cubos de tamanho médio (aproximadamente 1 cm).  Tente manter os pedaços de tamanho parecido para garantir um cozimento uniforme.
#
# 2. **Refogar:** Aqueça o azeite de oliva em uma panela grande e funda (de preferência uma panela de fundo grosso). Adicione a cebola e o alho e refogue em fogo médio até que a cebola esteja translúcida (aproximadamente 5 minutos).
#
# 3. **Adicionar os outros legumes:** Adicione a berinjela e o pimentão (se estiver usando) e cozinhe por mais 5 minutos, mexendo ocasionalmente.
#
# 4. **Acrescentar tomates:** Junte os tomates picados e misture bem. Adicione o orégano, o sal, a pimenta e o açúcar (se usar). Deixe ferver.
#
# 5. **Cozinhar:** Reduza o fogo para baixo, tampe a panela e cozinhe em fogo baixo por 20-30 minutos, ou até que os legumes estejam macios, mas ainda mantenham sua forma.  Mexa ocasionalmente para evitar que grude no fundo da panela.
#
# 6. **Finalização:**  Adicione o manjericão fresco picado nos últimos 5 minutos de cozimento.  Prove e ajuste os temperos se necessário.
#
# 7. **Servir:** Sirva quente ou frio. O Ratatouille é ótimo como acompanhamento de carnes, aves, peixes ou simplesmente com pão.
#
#
# **Observações:**
#
# * Você pode adicionar outras ervas de sua preferência, como tomilho ou alecrim.
# * Se preferir uma consistência mais cremosa, você pode usar um pouco de caldo de tomate ou água durante o cozimento.
# * Para uma versão ainda mais saborosa, você pode assar os legumes no forno antes de refogá-los.
#
#
# Aproveite sua Ratatouille!

# %%
prompt2 = """Estou fazendo uma dieta e gostaria de uma receita com baixo teor calórico e rica em proteínas.
          Resultado:
          {'receita': 'Yakisoba Vegan', 'similarity': 0.7459560632705688},
          {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.736324667930603},
          {'receita': 'Bacalhau com Natas', 'similarity': 0.7186410427093506},
          {'receita': 'Boeuf Bourguignon', 'similarity': 0.7142635583877563},
          {'receita': 'Brownie de Limão', 'similarity': 0.7098664045333862}

Com base nas avaliações dos produtos apresentados, analise cada um deles em relação à sua busca.
"""

# %%
response = modelGemini.generate_content(f"{prompt2}, para a receita mais semelhante, gere a receita passo a passo de acordo com {df}")
display(Markdown(response.text))
# Out:
# A sua busca é por uma receita com baixo teor calórico e rica em proteínas.  Vamos analisar as sugestões:
#
#
# * **Yakisoba Vegan (similaridade 0.75):**  Apesar de ter uma boa similaridade, com 300 calorias e 8g de proteína por porção, não é a melhor opção para uma dieta focada em baixo teor calórico e alta proteína. A quantidade de carboidratos (45g) também é considerável.
#
# * **Camarão com caldo de moqueca (similaridade 0.74):** Com 400 calorias e 25g de proteína,  é melhor que o Yakisoba em termos de proteína, mas ainda não é ideal em termos de calorias.
#
# * **Bacalhau com Natas (similaridade 0.72):**  450 calorias e 35g de proteína.  A quantidade de proteína é boa, mas as calorias permanecem altas.
#
# * **Boeuf Bourguignon (similaridade 0.71):** 550 calorias e 45g de proteína.  Alta em proteína, mas muito alta em calorias.
#
# * **Brownie de Limão (similaridade 0.71):**  Não se encaixa na sua busca por ser uma sobremesa rica em calorias (375) e baixa em proteínas (5g).
#
#
# **Conclusão:** Nenhuma das receitas sugeridas se encaixa perfeitamente no seu critério de "baixo teor calórico e rica em proteínas". As opções com mais proteínas também são as mais calóricas.
#
#
# **Sugestão de Adaptação da Receita Yakisoba Vegan (para reduzir calorias):**
#
# Para tornar o Yakisoba Vegan mais adequado à sua dieta, sugiro as seguintes modificações:
#
# **Nome:** Yakisoba Vegan Light
#
# **Ingredientes:**
#
# * 100g de macarrão de arroz integral (em vez de macarrão de arroz branco comum, que tem mais carboidratos)
# * 1 xícara de repolho picado finamente (mais fibras, menos calorias)
# * ½ xícara de cenoura ralada
# * ½ xícara de brócolis em floretes
# * 1/4 xícara de cogumelos fatiados (rico em proteínas e baixo em calorias)
# * 2 colheres de sopa de molho shoyu light (ou tamari para opção sem glúten)
# * 1 colher de sopa de gengibre ralado
# * 1 dente de alho picado
# * 1 colher de sopa de óleo de gergelim (ou um pouco de azeite extra virgem)
# * Proteína extra: Adicione tofu firme grelhado (100g) ou edamame (1/2 xícara). Essas opções irão aumentar consideravelmente o conteúdo proteico.
# * Sementes de gergelim para polvilhar (opcional).
#
# **Modo de preparo:**
#
# 1. Cozinhe o macarrão de arroz integral de acordo com as instruções da embalagem. Escorra e reserve.
# 2. Aqueça o óleo de gergelim em uma wok ou frigideira grande. Adicione o alho e o gengibre e refogue por 1 minuto.
# 3. Adicione a cenoura, o brócolis e os cogumelos e refogue por 3-4 minutos, até ficarem macios.
# 4. Adicione o repolho e cozinhe por mais 2 minutos, até murchar.
# 5. Adicione o macarrão de arroz cozido, o tofu ou edamame (se usar) e o molho shoyu light. Misture bem para combinar todos os ingredientes.
# 6. Sirva polvilhado com sementes de gergelim (opcional).
#
#
# Esta versão adaptada do Yakisoba Vegan terá menos calorias e mais proteínas do que a receita original. Lembre-se que as calorias e os macros podem variar levemente dependendo dos ingredientes específicos usados. É sempre recomendável consultar um nutricionista para um plano alimentar personalizado.

# %%
prompt3 = """Quais receitas têm menos de 400 calorias e mais de 20g de proteína por porção?
          Resultado:
          {'receita': 'Bacalhau com Natas', 'similarity': 0.7464921474456787},
          {'receita': 'Nhoque à Bolonhesa', 'similarity': 0.7149672508239746},
          {'receita': 'Boeuf Bourguignon', 'similarity': 0.7100570797920227},
          {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.700055718421936},
          {'receita': 'Berinjela Mediterrânea', 'similarity': 0.6947089433670044}

Com base nas avaliações dos produtos apresentados, analise cada um deles em relação à sua busca.
"""

# %%
response = modelGemini.generate_content(f"{prompt3}, para a receita mais semelhante, gere a receita passo a passo de acordo com {df}")
display(Markdown(response.text))
# Out:
# A lista de resultados apresenta receitas com mais de 20g de proteína e menos de 400 calorias por porção, mas a similaridade é calculada em relação a um conjunto de dados desconhecido.  Precisamos analisar a tabela fornecida para avaliar a adequação de cada receita.
#
# **Análise das Receitas:**
#
# Das receitas sugeridas pela similaridade, apenas o **Camarão com caldo de moqueca** está na tabela fornecida.  No entanto, suas calorias são 400, não atendendo ao critério de menos de 400 calorias.  As outras receitas sugeridas (Bacalhau com Natas, Nhoque à Bolonhesa, Boeuf Bourguignon, Berinjela Mediterrânea) também são encontradas na tabela, mas também não atendem aos critérios especificados.
#
#
# **Receita Passo a Passo (Camarão com Caldo de Moqueca):**
#
# Como o Camarão com caldo de moqueca tem 400 calorias, e o objetivo é menos que 400, a receita precisará ser ajustada para reduzir as calorias.  Uma forma de fazer isso é reduzir a quantidade de óleo ou usar um óleo com menos calorias.
#
# **Ingredientes (adaptados para reduzir calorias):**
#
# * 250g de camarão limpo (aproximadamente 250 calorias, para ter no máximo 350)
# * 1 colher de sopa de azeite extra virgem (40 calorias)
# * 1/2 cebola pequena, picada
# * 1 dente de alho picado
# * 1/2 xícara de leite de coco light (cerca de 25 calorias)
# * 1/4 xícara de caldo de peixe (baixo em sódio) (cerca de 5 calorias)
# * 1 colher de sopa de coentro picado
# * Suco de 1/2 limão
# * Sal e pimenta a gosto
#
# **Modo de preparo:**
#
# 1. Tempere os camarões com o suco de limão, sal e pimenta. Reserve.
# 2. Aqueça o azeite em uma panela média em fogo médio. Adicione a cebola e o alho e refogue até ficarem macios, cerca de 3 minutos.
# 3. Adicione o leite de coco light e o caldo de peixe. Deixe ferver.
# 4. Adicione os camarões e cozinhe até ficarem rosados, cerca de 2-3 minutos.
# 5. Retire do fogo e misture o coentro.
# 6. Sirva quente, acompanhado de arroz integral, por exemplo, para adicionar fibras e reduzir as calorias.
#
#
# **Observação:**  É importante ressaltar que as calorias são aproximadas e podem variar dependendo dos ingredientes usados. Para uma contagem mais precisa das calorias, utilize um aplicativo ou site de contagem de calorias. Esta receita modificada tem o objetivo de se aproximar do critério solicitado, mas um ajuste mais refinado pode ser necessário dependendo dos ingredientes específicos utilizados.  A receita original tem 400 calorias. Com estas alterações, provavelmente irá reduzir um pouco.
#
#
# Para encontrar receitas que se enquadrem perfeitamente nos critérios (menos de 400 calorias e mais de 20g de proteína), seria necessário consultar um banco de dados de receitas com informações nutricionais detalhadas e filtrar os resultados de acordo com esses critérios.  A tabela fornecida não contém receitas suficientes que se encaixam nos parâmetros.

# %%
prompt4 = """Possuo em casa: feijão, arroz, carne em casa, qual receita eu poderia fazer?
          Resultado:
          {'receita': 'Feijoada', 'similarity': 0.8013175129890442},
          {'receita': 'Berinjela Mediterrânea', 'similarity': 0.7195606827735901},
          {'receita': 'Nhoque à Bolonhesa', 'similarity': 0.7178099155426025},
          {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.7120342254638672},
          {'receita': 'Ratatouille', 'similarity': 0.7083571553230286}

Com base nas avaliações dos produtos apresentados, analise cada um deles em relação à sua busca.
"""

# %%
response = modelGemini.generate_content(f"{prompt4}, para a receita mais semelhante, gere a receita passo a passo de acordo com {df}")
display(Markdown(response.text))
# Out:
# A análise das receitas sugere que você tem ingredientes para diversas opções, mas a Feijoada é a mais próxima da combinação "feijão, arroz e carne".  Vamos analisar as sugestões:
#
#
# * **Feijoada (similaridade 0.80):**  A combinação perfeita!  Você tem todos os ingredientes principais (embora a receita possa precisar de linguiça e outros cortes de carne além do que já possui). Esta é a melhor opção.
#
# * **Berinjela Mediterrânea (similaridade 0.72):**  Esta receita não utiliza feijão nem arroz, apenas a berinjela, que você não mencionou ter.
#
# * **Nhoque à Bolonhesa (similaridade 0.72):**  Requer ingredientes adicionais que você provavelmente não tem em casa (batata, farinha, etc.).  A carne poderia ser usada no molho bolonhesa, mas não é o foco principal.
#
# * **Camarão com caldo de moqueca (similaridade 0.71):** Necessita de camarão, um ingrediente que você não mencionou ter.
#
# * **Ratatouille (similaridade 0.71):**  Esta receita também não inclui feijão ou arroz, necessitando de abobrinha, berinjela, tomate e pimentão, ingredientes que você também não relatou ter.
#
#
# **Receita Passo a Passo da Feijoada (adaptada para ingredientes disponíveis):**
#
# Esta receita é uma versão simplificada, adaptando-se aos ingredientes que você já possui. Se tiver outros tipos de carne, sinta-se livre para adicioná-los.
#
# **Ingredientes:**
#
# * 1 kg de Feijão Preto (secar e lavar bem)
# * 500g de Carne (qualquer corte, pode ser em cubos)
# * 1 Cebola média picada
# * 2 Dentes de alho picados
# * 2 Folhas de Louro
# * 1 Colher (sopa) de Óleo
# * Sal e Pimenta do reino a gosto
# * Arroz (para acompanhar)
#
#
# **Modo de Preparo:**
#
# 1. **Deixe o feijão de molho:**  Deixe o feijão preto de molho em água fria por pelo menos 6 horas, ou de preferência, durante a noite. Isso ajuda a reduzir o tempo de cozimento e deixar o feijão mais macio.
# 2. **Cozinhe a carne:** Em uma panela de pressão, doure a carne em cubos com o óleo. Adicione a cebola e o alho e refogue até ficarem macios.
# 3. **Adicione o feijão:** Escorra o feijão e adicione-o à panela com a carne, cebola e alho. Adicione as folhas de louro, sal e pimenta-do-reino.
# 4. **Cozinhe na pressão:** Adicione água suficiente para cobrir o feijão (aproximadamente 2 litros). Feche a panela de pressão e cozinhe em fogo alto até pegar pressão. Depois, reduza o fogo e cozinhe por aproximadamente 40 minutos.
# 5. **Verifique o feijão:** Após 40 minutos, verifique se o feijão está macio. Se necessário, cozinhe por mais alguns minutos.
# 6. **Sirva:** Retire as folhas de louro. Sirva a feijoada acompanhada de arroz branco.
#
#
# **Observações:**
#
# * Se quiser uma feijoada mais tradicional, adicione linguiça, costelinha de porco e outros ingredientes comuns à receita.
# * Ajuste a quantidade de água conforme necessário durante o cozimento. O feijão deve ficar cozido, mas não muito molhado.
# * Você pode adicionar outros temperos a gosto, como cominho, páprica, ou pimenta malagueta.
#
#
# Lembre-se que essa é uma receita adaptada.  O resultado pode variar levemente dependendo do tipo de carne e dos temperos que você usar.  Bom apetite!

# %%
sentence = "Quais receitas levam mais de 1 hora para preparar?"
similar_products = search_similar_products(sentence)
similar_products
# Out:
# [{'receita': 'Feijoada', 'similarity': 0.7097395658493042},
#  {'receita': 'Pavlova', 'similarity': 0.6768515706062317},
#  {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.6693881750106812},
#  {'receita': 'Boeuf Bourguignon', 'similarity': 0.666885495185852},
#  {'receita': 'Brownie de Limão', 'similarity': 0.6620928049087524}]

# %%
prompt5 = """Quais receitas levam mais de 1 hora para preparar?
          Resultado:
         {'receita': 'Feijoada', 'similarity': 0.7097395658493042},
         {'receita': 'Pavlova', 'similarity': 0.6768515706062317},
         {'receita': 'Camarão com caldo de moqueca', 'similarity': 0.6693881750106812},
         {'receita': 'Boeuf Bourguignon', 'similarity': 0.666885495185852},
         {'receita': 'Brownie de Limão', 'similarity': 0.6620928049087524}

Com base nas avaliações dos produtos apresentados, analise cada um deles em relação à sua busca.
"""

# %%
response = modelGemini.generate_content(f"{prompt5}")
display(Markdown(response.text))
# Out:
# A lista apresentada mostra receitas que, segundo um modelo de similaridade (não especificado, mas presumivelmente baseado em texto descritivo das receitas), levam mais de uma hora para preparar.  A similaridade indica a probabilidade de cada receita corresponder à busca por receitas com tempo de preparo superior a uma hora.  Quanto maior a similaridade (mais próxima de 1), maior a probabilidade.
#
#
# Vamos analisar cada receita individualmente considerando o tempo de preparo, baseado no conhecimento geral dessas receitas:
#
#
# * **Feijoada (similaridade 0.71):**  Esta é uma receita tipicamente demorada, devido ao longo tempo de cozimento do feijão e dos ingredientes.  A alta similaridade condiz com a expectativa.
#
# * **Pavlova (similaridade 0.68):**  A Pavlova exige tempo para o preparo do merengue e para assar corretamente, além do tempo de resfriamento. A similaridade é razoável, refletindo o tempo de preparo considerável.
#
# * **Camarão com caldo de moqueca (similaridade 0.67):**  O tempo de preparo depende da preparação do caldo e do cozimento dos camarões, podendo levar mais de uma hora, dependendo da receita.  A similaridade é consistente com a possibilidade de tempo de preparo longo.
#
# * **Boeuf Bourguignon (similaridade 0.67):** Este é um guisado francês que requer um longo tempo de cozimento para que a carne fique macia.  A alta similaridade se justifica pelo longo tempo de preparo.
#
# * **Brownie de Limão (similaridade 0.66):**  Brownies, em geral, não levam mais de uma hora para serem preparados.  A similaridade menor sugere que este brownie específico talvez tenha algum passo que o diferencie e alongue seu tempo de preparo (um longo tempo de resfriamento, por exemplo, ou a preparação de algum ingrediente complexo).  Essa é a receita que mais se distancia da expectativa em relação ao tempo.
#
#
# **Conclusão:**
#
# A lista reflete bem a busca por receitas demoradas, com exceção do brownie de limão, que precisa de uma avaliação mais aprofundada para verificar se o tempo de preparo extra se justifica.  A similaridade numérica oferece uma medida quantitativa de quão bem cada receita se encaixa no critério de tempo de preparo, o que é útil para a organização e apresentação dos resultados.
